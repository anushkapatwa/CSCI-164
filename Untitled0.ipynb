# %% [markdown]
# <a href="https://colab.research.google.com/github/anushkapatwa/CSCI-164/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings(action = 'ignore')


from transformers import pipeline
from transformers.utils import logging
logging.set_verbosity(40)


from IPython.display import Image

# %%
# !gdown 1cnTENQcwMXe7o1vOtx01RDbbnp6UroND
x = "silver-tabby-cat-sitting-on-green-background-free-photo.jpg"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1cnTENQcwMXe7o1vOtx01RDbbnp6UroND
# To: /content/silver-tabby-cat-sitting-on-green-background-free-photo.jpg
# 100% 24.5k/24.5k [00:00<00:00, 55.3MB/s]

# %% [markdown]
# > Add blockquote

# %%
# !gdown 1ify4y6aWXrTY6vfgWORTr5wyyc4LoSTc
a = "download.jpeg"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ify4y6aWXrTY6vfgWORTr5wyyc4LoSTc
# To: /content/download.jpeg
# 100% 7.31k/7.31k [00:00<00:00, 19.7MB/s]

# %%
# !gdown 1woJysorQAvoYoXiDp3CY62w65HqyFdlu
b = "360_F_313477805_FjdtYLHA78oQBs4sYkPhVwNFDBotcCGi.jpg"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1woJysorQAvoYoXiDp3CY62w65HqyFdlu
# To: /content/360_F_313477805_FjdtYLHA78oQBs4sYkPhVwNFDBotcCGi.jpg
# 100% 44.0k/44.0k [00:00<00:00, 47.9MB/s]

# %%
### Task: Image captioning
captioner = pipeline(task="image-to-text",
                     model="nlpconnect/vit-gpt2-image-captioning")

# %%
captioner2 = pipeline("image-to-text", model="Salesforce/blip-image-captioning-base")
# Out:
# config.json:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/506 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]

# %%
captioner3 = pipeline("image-to-text", model="Salesforce/blip2-opt-2.7b")
# Out:
# config.json:   0%|          | 0.00/1.03k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/122k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/10.0G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/141 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/882 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.56M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/23.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/548 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/432 [00:00<?, ?B/s]

# %% [markdown]
# #GPT model

# %%
print("Image 1")
captioner(x)
# Out:
# Image 1
# [{'generated_text': 'a cat sitting on the grass looking at the camera '}]

# %%
print("Image 2")
captioner(a)
# Out:
# Image 2
# [{'generated_text': 'a large building with a large clock on the top '}]

# %%
print("Image 3")
captioner(b)
# Out:
# Image 3
# [{'generated_text': 'a tennis racket is on a tennis court '}]

# %% [markdown]
# #Blip Model

# %%
print("Image 1")
captioner2(x)
# Out:
# Image 1
# [{'generated_text': 'a kitten sitting on the grass'}]

# %%
print("Image 2")
captioner2(a)
# Out:
# Image 2
# [{'generated_text': 'the office building at the corner of the road'}]

# %%
print("Image 3")
captioner2(b)
# Out:
# Image 3
# [{'generated_text': 'two pings and a racket on a table'}]

# %% [markdown]
# #Blip 2

# %%
print("Image 1")
captioner3(x)
# Out:
# Image 1
# [{'generated_text': 'a gray and white kitten sitting on a green field\n'}]

# %%
print("Image 2")
captioner3(a)
# Out:
# Image 2
# [{'generated_text': 'the office building in the city with trees and bushes\n'}]

# %%
print("Image 3")
captioner3(b)
# Out:
# Image 3
# [{'generated_text': 'two ping pong paddles and a ball on a table\n'}]
